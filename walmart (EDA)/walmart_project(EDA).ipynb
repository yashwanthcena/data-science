# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
test_df=pd.read_csv('test.csv')
train_df=pd.read_csv('train.csv')
features_df=pd.read_csv('features.csv')
stores_df=pd.read_csv('stores.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %%
features_df.head(10)
# Out:
#    Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1  2010-02-05        42.31  ...  211.096358         8.106      False
# 1      1  2010-02-12        38.51  ...  211.242170         8.106       True
# 2      1  2010-02-19        39.93  ...  211.289143         8.106      False
# 3      1  2010-02-26        46.63  ...  211.319643         8.106      False
# 4      1  2010-03-05        46.50  ...  211.350143         8.106      False
# 5      1  2010-03-12        57.79  ...  211.380643         8.106      False
# 6      1  2010-03-19        54.58  ...  211.215635         8.106      False
# 7      1  2010-03-26        51.45  ...  211.018042         8.106      False
# 8      1  2010-04-02        62.27  ...  210.820450         7.808      False
# 9      1  2010-04-09        65.86  ...  210.622857         7.808      False
#
# [10 rows x 12 columns]

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
features_df.describe()
# Out:
#              Store  Temperature  ...          CPI  Unemployment
# count  8190.000000  8190.000000  ...  7605.000000   7605.000000
# mean     23.000000    59.356198  ...   172.460809      7.826821
# std      12.987966    18.678607  ...    39.738346      1.877259
# min       1.000000    -7.290000  ...   126.064000      3.684000
# 25%      12.000000    45.902500  ...   132.364839      6.634000
# 50%      23.000000    60.710000  ...   182.764003      7.806000
# 75%      34.000000    73.880000  ...   213.932412      8.567000
# max      45.000000   101.950000  ...   228.976456     14.313000
#
# [8 rows x 10 columns]

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
dataset_m=features_df.merge(stores_df,how='inner',on='Store')
dataset_m.head()
# Out:
#    Store        Date  Temperature  ...  IsHoliday  Type    Size
# 0      1  2010-02-05        42.31  ...      False     A  151315
# 1      1  2010-02-12        38.51  ...       True     A  151315
# 2      1  2010-02-19        39.93  ...      False     A  151315
# 3      1  2010-02-26        46.63  ...      False     A  151315
# 4      1  2010-03-05        46.50  ...      False     A  151315
#
# [5 rows x 14 columns]

# %%
from datetime import  datetime
dataset_m['Date']=pd.to_datetime(dataset_m['Date'])
test_df['Date']=pd.to_datetime(test_df['Date'])
train_df['Date']=pd.to_datetime(train_df['Date'])

dataset_m['week']=dataset_m.Date.dt.isocalendar().week
dataset_m['year']=dataset_m.Date.dt.isocalendar().year

dataset_m.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  ...  Type    Size  week  year
# 8185     45 2013-06-28        76.05       3.639  ...     B  118221    26  2013
# 8186     45 2013-07-05        77.50       3.614  ...     B  118221    27  2013
# 8187     45 2013-07-12        79.37       3.614  ...     B  118221    28  2013
# 8188     45 2013-07-19        82.84       3.737  ...     B  118221    29  2013
# 8189     45 2013-07-26        76.06       3.804  ...     B  118221    30  2013
#
# [5 rows x 16 columns]

# %%
train_df_1=train_df.merge(dataset_m,how='inner',on=['Store','Date','IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
train_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     150681 non-null  float64
#  8   MarkDown2     111248 non-null  float64
#  9   MarkDown3     137091 non-null  float64
#  10  MarkDown4     134967 non-null  float64
#  11  MarkDown5     151432 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
#  16  week          421570 non-null  UInt32
#  17  year          421570 non-null  UInt32
# dtypes: UInt32(2), bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 52.7+ MB

# %%
def scatter(train_def_1,column):
  plt.figure()
  plt.scatter(train_df_1[column],train_df_1['Weekly_Sales'])
  plt.xlabel(column)
  plt.ylabel('Weekly_sales')

# %%
scatter(train_df_1,'Store')

# %%
scatter(train_df_1,'Dept')

# %%
weekly_sales_2011= train_df_1[train_df_1['year']==2011]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_2010= train_df_1[train_df_1['year']==2010]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_2012= train_df_1[train_df_1['year']==2012]['Weekly_Sales'].groupby(train_df_1['week']).mean()
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,10))
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='blue')
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='green')

plt.xticks(np.arange(1,60,step=1))
plt.title('average weekly sales per year',fontsize=20)
plt.xlabel('week',fontsize=16)
plt.ylabel('sales',fontsize=16)
plt.legend(['2010','2011','2012'],fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_store=train_df_1['Weekly_Sales'].groupby(train_df_1['Store']).mean()

# %%
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    29161.210415
# 5     5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
weekly_sales_store_df=pd.DataFrame(weekly_sales_store)

# %%
  weekly_sales_store_df.sort_values('Weekly_Sales',ascending=False).style.bar(align='left',width=98,color='yellow')
# Out:
# <style  type="text/css" >
# #T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 98.0%, transparent 98.0%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 96.6%, transparent 96.6%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 95.1%, transparent 95.1%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 89.4%, transparent 89.4%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 87.5%, transparent 87.5%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 85.3%, transparent 85.3%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 79.2%, transparent 79.2%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 67.6%, transparent 67.6%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 66.8%, transparent 66.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 63.9%, transparent 63.9%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 61.3%, transparent 61.3%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 59.0%, transparent 59.0%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 58.6%, transparent 58.6%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 57.0%, transparent 57.0%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 55.8%, transparent 55.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 54.7%, transparent 54.7%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 51.8%, transparent 51.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 45.3%, transparent 45.3%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 42.8%, transparent 42.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 40.6%, transparent 40.6%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 39.3%, transparent 39.3%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 38.1%, transparent 38.1%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 35.1%, transparent 35.1%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 34.9%, transparent 34.9%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 33.9%, transparent 33.9%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 33.5%, transparent 33.5%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 32.4%, transparent 32.4%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 31.7%, transparent 31.7%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 26.5%, transparent 26.5%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 25.6%, transparent 25.6%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 25.0%, transparent 25.0%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 21.1%, transparent 21.1%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 21.0%, transparent 21.0%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 15.8%, transparent 15.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row34_col0,#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 14.9%, transparent 14.9%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 14.2%, transparent 14.2%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 13.2%, transparent 13.2%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 12.4%, transparent 12.4%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 11.3%, transparent 11.3%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 9.8%, transparent 9.8%);
#         }#T_2b3a7dac_1d1f_11ec_afb1_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 5.3%, transparent

# %%
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_store.index,weekly_sales_store.values,palette='dark')
plt.xlabel('store number',fontsize=16)
plt.ylabel('average sales per store',fontsize=16)
plt.title('average sales',fontsize=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
weekly_sales_dept=train_df_1['Weekly_Sales'].groupby(train_df_1['Dept']).mean()
weekly_sales_dept_df=pd.DataFrame(weekly_sales_dept)

# %%
weekly_sales_dept_df.head()
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515

# %%
weekly_sales_dept_df.sort_values("Weekly_Sales",ascending=False).style.bar( align='left',color='red',width=50)
# Out:
# <style  type="text/css" >
# #T_6d34825e_1d22_11ec_afb1_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 50.0%, transparent 50.0%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 46.4%, transparent 46.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 40.6%, transparent 40.6%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 33.6%, transparent 33.6%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 30.2%, transparent 30.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 30.1%, transparent 30.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 29.9%, transparent 29.9%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 29.0%, transparent 29.0%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 22.4%, transparent 22.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 22.2%, transparent 22.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 20.4%, transparent 20.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 20.1%, transparent 20.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 18.0%, transparent 18.0%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 17.3%, transparent 17.3%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 16.1%, transparent 16.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 15.9%, transparent 15.9%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 14.6%, transparent 14.6%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 14.2%, transparent 14.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 13.4%, transparent 13.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 13.3%, transparent 13.3%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 12.8%, transparent 12.8%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 12.2%, transparent 12.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 10.4%, transparent 10.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row23_col0,#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 10.3%, transparent 10.3%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 10.1%, transparent 10.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.9%, transparent 9.9%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.6%, transparent 9.6%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row28_col0,#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.5%, transparent 9.5%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.2%, transparent 9.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 8.9%, transparent 8.9%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 8.1%, transparent 8.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.8%, transparent 7.8%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.2%, transparent 7.2%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 7.1%, transparent 7.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 6.8%, transparent 6.8%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 6.0%, transparent 6.0%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 5.4%, transparent 5.4%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 5.1%, transparent 5.1%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 5.0%, transparent 5.0%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 4.9%, transparent 4.9%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row42_col0,#T_6d34825e_1d22_11ec_afb1_0242ac1c0002row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 4.5%, transparent 4.5%);
#         }#T_6d34825e_1d22_11ec_afb1_0242ac1c

# %%
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_dept.index,weekly_sales_dept.values)
plt.title("average sales by dept")
plt.xlabel('dept')
plt.ylabel('sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
